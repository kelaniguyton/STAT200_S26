# %% [markdown]
# # **Practice 03: Data Types and Data Structures**
#
# #### **Kelani Guyton**

# %% [markdown]
# ---
#
# **IMPORTANT**:
# - Before starting the lab, save a copy to your google drive by navigating to `File > Save a copy in Drive` <br>
#
# <br>
#
#
# **Instructions**: Complete the lab below.
#
# - <font color=red>Tasks</font> indicated in red must be completed to receive credit
# - Include all code for your work
# - Include markdown cells with written answers explaining your work when prompted
# - **NOTE: Your completed lab must be submitted to Canvas as a .ipynb file by the end of the lab session**
# ---

# %% [markdown]
# <br>

# %% [markdown]
# ####<font color=red>Organized</font>
#
# **Answers should be organized in the following format for organization and readability**

# %% [markdown]
# <font color=red>Example task 1</font>

# %%
# 1.

# This will be the code block to answer the first part of a task

# %% [markdown]
# 1. This will be the text answer/explanation (if prompted) for the first task

# %% [markdown]
# <font color=red>Example task 2</font>

# %%
# 2.

# This will be the code block to answer the second part of a task

# %% [markdown]
# 2. This will be the text answer/explanation (if prompted) for the second task

# %% [markdown]
# <br>
#
# Continue this format for the remaining subtasks

# %% [markdown]
# <br>

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ####<font color=red>Task 1</font> - Collecting data
#
# Collect the following data from at least 4 of your neighbors
# * Major
# * Year in school (freshman, sophomore, etc.)
# * Pets (`TRUE` or `FALSE` with no quotes)
# * Name of one pet (if no pet, then use `NA` with no quotes)
# * Hours slept night before
#
#
# If members of your group would not like to provide certain information, that is okay! Simply enter `NA` in their entry

# %% [markdown]
# <font color=red>Task 1.1</font>  Create 5 vectors using `c()` for each of the variables (use variable names that are useful!)

# %%
#1.1

#vectors with sample data
major <- c("statistics", "psychology", "mathematics", "economics" )
year <-c("freshman", "senior", "sophomore", "freshman")
pets <- c(FALSE, TRUE, FALSE, TRUE)
pet_name <- c(NA, "petunia", NA, "rio")
sleep <- c(6, 7, 5, 6)

# %% [markdown]
# <font color=red>Task 1.2</font> Using the five vectors from Task 1.1, create a data frame and store the data frame as the variable `pets`.

# %%
#1.2

#creating data frame with pre-defined vectors
pets <- data.frame(major, year, pets, pet_name, sleep)

# %%
#data

pets
# Out:
#   major       year      pets  pet_name sleep
# 1 statistics  freshman  FALSE NA       6
# 2 psychology  senior     TRUE petunia  7
# 3 mathematics sophomore FALSE NA       5
# 4 economics   freshman   TRUE rio      6

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 1.3</font> Use the `dim()` function to determine the number of observations and variables in the data frame `pets`.

# %%
dim(pets)
# Out:
# [1] 4 5

# %% [markdown]
# Observations is refering to the number of rows, which is 4. Variables is refering to the number of columns, which is 5.

# %% [markdown]
# <font color=red>Task 1.4</font> Use the `str()` function to determine which of the variables in the data frame are character data type.

# %% [markdown]
# <br>

# %%
#1.4

#check variable types
str(pets)
# Out:
# 'data.frame':	4 obs. of  5 variables:
#  $ major   : chr  "statistics" "psychology" "mathematics" "economics"
#  $ year    : chr  "freshman" "senior" "sophomore" "freshman"
#  $ pets    : logi  FALSE TRUE FALSE TRUE
#  $ pet_name: chr  NA "petunia" NA "rio"
#  $ sleep   : num  6 7 5 6

# %%
#checking a single column, we can use the $
str(pets$major)
# Out:
#  chr [1:4] "statistics" "psychology" "mathematics" "economics"

# %% [markdown]
# The variables classified as character are `major`, `year` and `pet_name`.

# %% [markdown]
# <font color=red>Task 1.5</font> Overwrite the names of the data frame to reflect the following:
#   * `sdsu_major`
#   * `school_year`
#   * `pets_true_false`
#   * `pet_name`
#   * `sleep_hours`

# %%
#1.5

#overwrite column names
names (pets) <- c("sdsu_major", "school_year", "pet_true_false", "pet name", "sleep_hours")

#check
names(pets)
# Out:
# [1] "sdsu_major"     "school_year"    "pet_true_false" "pet name"
# [5] "sleep_hours"

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 1.6</font> Assign the name of each student as the row names of the data frame using the `rownames()` functions. Show the results to verify this was performed correctly.

# %%
#1.6

#assigning row names
row.names(pets) <- c("Minoree", "Dilynn", "Kayden", "Kairo")

# %%
#check
pets
# Out:
#         sdsu_major  school_year pet_true_false pet name sleep_hours
# Minoree statistics  freshman    FALSE          NA       6
# Dilynn  psychology  senior       TRUE          petunia  7
# Kayden  mathematics sophomore   FALSE          NA       5
# Kairo   economics   freshman     TRUE          rio      6

# %% [markdown]
# <br>
#
# <br>

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ####<font color=red>Task 2</font> - Manipulating data types and coercion

# %% [markdown]
# <font color=red>Task 2.1</font>
#
# 1. Choose a number and assign it to a variable.
# 2. Check the data type of your variable using the `class()` function.
# 3. Convert the variable to a character using the `as.character()` function and reassign to the same variable.
# 4. Again, check the data type of your variable using the `class()` function.
# 5. In a text cell, write what you observe in complete sentences.

# %%
#2.1

#choosing a number & assigning to variable
k <- 12

# %%
#2.1.2

#check the default class of the variables
class(k)
# Out:
# [1] "numeric"

# %%
#2.1.3

#change type to character
k <- as.character(k)
k
# Out:
# [1] "12"

# %%
#2.1.4

#check class of variable
class(k)
# Out:
# [1] "character"

# %% [markdown]
# The value 12 was assigned to `k` was initially a numeric class. The function `as.character()` converted this `numeric` value to `character` class, as indicated by the apostrophes in the output.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 2.2</font>
# 1. Convert the number `1` into a logical data type using the `as.logical()` function. What are your observations?
# 2. Convert the number `-33.8` into a logical data type using the `as.logical()` function. What are your observations?
# 3. Convert the number `0` into a logical data type using the `as.logical()` function. What are your observations?
# 4. Convert the number `2.7` into an integer data type using the `as.integer()` function. What are your observations? Is this what you expected?

# %%
#2.2.1

#convert 1 to logical with `as.logical()`
as.logical(1)
# Out:
# [1] TRUE

# %% [markdown]
# We observed that 1 is returned as TRUE.

# %%
#2.2.2

#convert -33.8 to logical with `as.logical()`
as.logical(-33.8)
# Out:
# [1] TRUE

# %% [markdown]
# We observed that -33.8 is returned as TRUE.

# %%
#2.2.3

#convert 0 to logical with `as.logical()`
as.logical(0)
# Out:
# [1] FALSE

# %% [markdown]
# All nonzero numbers are converted to a `TRUE` logical. A zero is converted to a `FALSE` logical.

# %%
#2.2.4

#convert 2.7 to an integer
as.integer(2.7)
# Out:
# [1] 2

# %% [markdown]
# It appears the `as.integer` function rounds down ot the nearest integer.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 2.3</font>
# 1. Convert the character `"5.3"` into a `numeric` data type using the `as.numeric()` function. What are your observations?
# 2. Convert the character `"5.3"` into a `logical` data type using the `as.logical()` function. What are your observations?
# 3. Convert the character `"TRUE"` into a `logical` data type using the `as.logical()` function. What are your observations?
# 3. Convert the character `"5.3"` into an `integer` data type using the `as.integer()` function. What are your observations?
# 4. Create a character string of text of your favorite place to eat and attempt to convert the character into a `numeric` data type. What are your observations?

# %%
#2.3.1

#convert "5.3" to a numeric
as.numeric("5.3")
# Out:
# [1] 5.3

# %% [markdown]
# Numbers in `character` class form can be converted into there corresponding `numeric` class form.

# %%
#2.3.2

#convert "5.3" to a logical
as.logical("5.3")
# Out:
# [1] NA

# %% [markdown]
# Numbers in `character` form produce an `NA` when converted to a logical.

# %%
#2.3.3

#convert "TRUE" to a logical
as.logical("TRUE")
# Out:
# [1] TRUE

# %% [markdown]
# Logicals in `character` form can be converted into their corresponding `logical` class form.

# %%
#2.3.4

#convert "5.3" to an integer
as.integer("5.3")
# Out:
# [1] 5

# %% [markdown]
# Decimals in `character` class form can be coverted into their corresponding `integer` class resulting frmo the floor function (rounding down)

# %%
#2.3.5

#
as.numeric("the taco stand")
# Out:
# Warning message:
# “NAs introduced by coercion”
# [1] NA

# %% [markdown]
# Text in character class produces an `NA` when converted to `numeric` class

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 2.4</font>
# 1. Convert the logical `TRUE` into a `numeric` data type using the `as.numeric()` function.  What are your observations?
# 2. Convert the logical `FALSE` into a `numeric` data type using the `as.numeric()` function.  What are your observations?
# 3. Convert the logical `TRUE` into a `character` data type using the `as.character()` function.  What are your observations?
# 4. Convert the logical `FALSE` into an `integer` data type using the `as.integer()` function.  What are your observations?

# %%
#2.4.1

as.numeric(TRUE)
# Out:
# [1] 1

# %% [markdown]
# A `TRUE` is equivalent to a `1` in `numeric` class.

# %%
#2.4.2

as.numeric(FALSE)
# Out:
# [1] 0

# %% [markdown]
# A `FALSE` is equivalent to a `0` in `numeric` class.

# %%
#2.4.3

as.character(TRUE)
# Out:
# [1] "TRUE"

# %% [markdown]
# A `TRUE` is equivalent to a `"TRUE"` in `character` class.

# %%
#2.4.4

as.integer(FALSE)
# Out:
# [1] 0

# %% [markdown]
# A `FALSE` is equivalent to a `0` in `integer` class.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 2.5</font>
# 1. Add a `character` data type to a `numeric` data type. What are your observations?
# 2. Add a `TRUE` logical to a `numeric` data type. What are you observations?
# 3. Add a `character` data type to a `logical` data type. What are your observations?

# %%
#2.5.1

#character + numeric
"7" + 12
# Out:
# Error in "7" + 12: non-numeric argument to binary operator
# Traceback:

# %% [markdown]
# We are unable to add a `character` class to a `numeric` class.

# %%
#2.5.2

#logical + numeric
TRUE + 6
# Out:
# [1] 7

# %% [markdown]
# Arithmetic operations with logicals consider a `TRUE` to be a value `1`.

# %%
#2.5.3

#character + logical
"32" + TRUE
# Out:
# Error in "32" + TRUE: non-numeric argument to binary operator
# Traceback:

# %% [markdown]
# Artithmetic operations with logicals consider `FALSE` to be a value `0` and `TRUE` to be `1`, but the operation produced an error since we are unable to add a `character` class to a `logical` class

# %% [markdown]
# <br>

# %% [markdown]
# <br>
#
# <br>

# %% [markdown]
# <br>
