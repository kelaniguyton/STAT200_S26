# %% [markdown]
# # **Practice 02: Variables and the R Workspace**
#
# #### **Kelani Guyton**

# %% [markdown]
# ---
# **Instructions**: Complete the assignment below.
# - <font color=red>Tasks</font> indicated in red must be completed to receive credit
# - Include all code for your work
# - Include markdown cells with written answers explaining your work when prompted
# - Your completed assignment must be submitted to Canvas as a .ipynb file by the deadline listed on Canvas
# ---

# %% [markdown]
# <br>

# %% [markdown]
# ####<font color=red>Organized</font>
#
# **Answers should be organized in the following format for organization and readability**

# %% [markdown]
# <font color=red>Example task 1</font>

# %%
# 1.

# This will be the code block to answer the first part of a task

# %% [markdown]
# 1. This will be the text answer/explanation (if prompted) for the first task

# %% [markdown]
# <font color=red>Example task 2</font>

# %%
# 2.

# This will be the code block to answer the second part of a task

# %% [markdown]
# 2. This will be the text answer/explanation (if prompted) for the second task

# %% [markdown]
# <br>
#
# Continue this format for the remaining subtasks

# %% [markdown]
# <br>

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ####<font color=red>Task 1</font>

# %% [markdown]
# <font color=red>Task 1.1</font> Let `a` equal 1, `b` equal 5, and `c` equal 6. Use `R` to assign these values to variables `a`, `b`, and `c`.

# %%
# 1.1

a <- 1
b <- 5
c <- 6

# %%
# 1.1
a = 1
b = 5
c = 6

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 1.2</font> Use `R` to calculate the solution to the quadratic formula
# \begin{align}
# x = \frac{-b \pm \sqrt{b^2 - 4 \times a \times c}}{2 \times a}
# \end{align}

# %%
# 1.2

x_plus <- (-b + sqrt(b^2 - 4 * a * c))   /   (2 * a)
x_plus
# Out:
# [1] -2

# %%
# 1.2

x_minus <- (-b - sqrt(b^2 - 4 * a * c)) / (2 * a)
x_minus
# Out:
# [1] -3

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 1.3</font> Use the `install.packages()` function to install the library `QuadRoot`

# %%
# 1.3

install.packages("QuadRoot")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 1.4</font> Load `QuadRoot` library using the `library()` function

# %%
# 1.4

library(QuadRoot)

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 1.5</font> There is a function `QuadRoot` that can calculate the solution to the quadratic equation.
#
# * Use the script below to solve and check your answer
# ```
# QuadRoot::QuadRoot(c(a, b, c))
# ```
# * In complete sentences, verify that your answer matches the answer from the `QuadRoot` function

# %%
QuadRoot:: QuadRoot(c(a, b, c))
# Out:
# [1] "The two x-intercepts for the quadratic equation are -2.0000 and -3.0000."

# %% [markdown]
# Yes, my answers match the answer generated from the 'QuadRoot' function

# %% [markdown]
# <br>
