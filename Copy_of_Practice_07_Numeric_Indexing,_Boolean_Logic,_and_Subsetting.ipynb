# %% [markdown]
# # **Practice 07: Numeric Indexing, Boolean Logic, and Subsetting**
#
# #### **Kelani Guyton**

# %% [markdown]
# ---
#
# **IMPORTANT**:
# - Before starting the lab, save a copy to your google drive by navigating to `File > Save a copy in Drive` <br>
#
# <br>
#
#
# **Instructions**: Complete the lab below.
#
# - <font color=red>Tasks</font> indicated in red must be completed to receive credit
# - Include all code for your work
# - Include markdown cells with written answers explaining your work when prompted
# - **NOTE: Your completed lab must be submitted to Canvas as a .ipynb file by the end of the lab session**
# ---

# %% [markdown]
# <br>

# %% [markdown]
# ####<font color=red>Organized</font>
#
# **Answers should be organized in the following format for organization and readability**

# %% [markdown]
# <font color=red>Example task 1</font>

# %%
# 1.

# This will be the code block to answer the first part of a task

# %% [markdown]
# 1. This will be the text answer/explanation (if prompted) for the first task

# %% [markdown]
# <font color=red>Example task 2</font>

# %%
# 2.

# This will be the code block to answer the second part of a task

# %% [markdown]
# 2. This will be the text answer/explanation (if prompted) for the second task

# %% [markdown]
# <br>
#
# Continue this format for the remaining subtasks

# %% [markdown]
# <br>

# %% [markdown]
# ---
#
# <br>

# %% [markdown]
# #### Packages

# %%
# install packages for today's lecture
install.packages("dslabs")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)

# %%
# load the necessary packages
library(dslabs)

# %% [markdown]
# <br>
#
# <br>

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ####<font color=red>Task 1</font> - Loading and Preprocessing the Dataset

# %% [markdown]
# <font color=red>Task 1.1</font> Today, we'll be working with salary data available online.
#
# * Run the following script to load the salary dataset for today's assignment.
#
# ```
# # load data frame
# data_url                       <- "https://raw.githubusercontent.com/khasenst/datasets_teaching/refs/heads/main/salary_data.csv"
# salary                         <- na.omit(read.csv(data_url, header = TRUE))
#
# # convert character variables to factors
# salary$Gender                  <- as.factor(salary$Gender)
# salary$Education.Level         <- as.factor(salary$Education.Level)
# salary$Job.Title               <- as.factor(salary$Job.Title)
#
# # reassign levels
# levels(salary$Education.Level) <-  c("missing", "BS", "BS", "HS",
#                                      "MS", "MS", "PhD", "PhD")
# salary$Education.Level         <- factor(salary$Education.Level, levels = c("missing", "HS", "BS", "MS", "PhD"))
# ```

# %%
# load data frame
data_url                       <- "https://raw.githubusercontent.com/khasenst/datasets_teaching/refs/heads/main/salary_data.csv"
salary                         <- na.omit(read.csv(data_url, header = TRUE))

# convert character variables to factors
salary$Gender                  <- as.factor(salary$Gender)
salary$Education.Level         <- as.factor(salary$Education.Level)
salary$Job.Title               <- as.factor(salary$Job.Title)

# reassign levels
levels(salary$Education.Level) <-  c("missing", "BS", "BS", "HS",
                                     "MS", "MS", "PhD", "PhD")
salary$Education.Level         <- factor(salary$Education.Level, levels = c("missing", "HS", "BS", "MS", "PhD"))

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 1.2</font> View the first few lines of the `salary` data frame using the `head()` function.

# %%
head(salary)
# Out:
#   Age Gender Education.Level Job.Title         Years.of.Experience Salary
# 1 32  Male   BS              Software Engineer  5                   90000
# 2 28  Female MS              Data Analyst       3                   65000
# 3 45  Male   PhD             Senior Manager    15                  150000
# 4 36  Female BS              Sales Associate    7                   60000
# 5 52  Male   MS              Director          20                  200000
# 6 29  Male   BS              Marketing Analyst  2                   55000

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 1.3</font> Use the `str()` function to determine the number of rows and columns in the `salary` data frame. Write your observations in a text cell.

# %%
str(salary)
# Out:
# 'data.frame':	6699 obs. of  6 variables:
#  $ Age                : int  32 28 45 36 52 29 42 31 26 38 ...
#  $ Gender             : Factor w/ 3 levels "Female","Male",..: 2 1 2 1 2 2 1 2 1 2 ...
#  $ Education.Level    : Factor w/ 5 levels "missing","HS",..: 3 4 5 3 4 3 4 3 3 5 ...
#  $ Job.Title          : Factor w/ 192 levels "Account Manager",..: 177 19 146 117 27 95 108 120 96 167 ...
#  $ Years.of.Experience: num  5 3 15 7 20 2 12 4 1 10 ...
#  $ Salary             : int  90000 65000 150000 60000 200000 55000 120000 80000 45000 110000 ...
#  - attr(*, "na.action")= 'omit' Named int [1:5] 173 261 3137 5248 6456
#   ..- attr(*, "names")= chr [1:5] "173" "261" "3137" "5248" ...

# %% [markdown]
# The `str()` function shows that the salary data frame has 6,699 observations (rows), and 6 variables (columns). The data includes age, gender, education level, job title, years of experience, and salary.

# %% [markdown]
# <br>
#
# <br>

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ####<font color=red>Task 2</font> - Numeric Indexing

# %% [markdown]
# <font color=red>Task 2.1</font>
#
# * Using numeric indexing, extract the second entry of the `Gender` variable in the `salary` data frame. Note there are multiple approaches.
#
# * Write your observations in a text cell.

# %%
# method 1
salary$Gender[2]

#method 2
salary[2, 2]
# Out:
# [1] Female
# Levels: Female Male Other
# [1] Female
# Levels: Female Male Other

# %% [markdown]
# Using the '$' index extracts the second entry of the Gender variable, which is female.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 2.2</font>
#
# * Using numeric indexing and the `ncol()` function, extract the last column of the `salary` data frame.
#
# * What is the data structure of your output [i.e. `class()`]?

# %%
salary[, ncol(salary)]
# Out:
#    [1]  90000  65000 150000  60000 200000  55000 120000  80000  45000 110000
#   [11]  75000 140000  65000 130000  40000 125000  90000 115000  35000 180000
#   [21]  80000 190000  50000  60000 140000  45000 110000  40000 140000  90000
#   [31] 250000  55000  75000  65000 170000  45000  60000 115000  40000 160000
#   [41]  80000 190000  60000  45000 130000  40000  75000 180000 120000  35000
#   [51] 130000  85000  60000 200000  50000  95000  65000 140000  55000 105000
#   [61] 170000  50000  80000 180000  35000  90000 120000  45000  90000 150000
#   [71]  65000  70000 190000  40000 120000  95000 160000 100000 180000  55000
#   [81]  70000  80000  30000 250000  40000  95000  45000  80000 135000  55000
#   [91] 120000  40000 105000 170000  75000  65000 160000  35000  90000 110000
#  [101]  45000  95000 150000  50000  80000 220000  50000  60000 100000  40000
#  [111] 110000  95000 130000  90000  35000  95000  65000 170000  45000 120000
#  [121] 100000 180000  50000  80000 140000  40000  95000 110000  50000 105000
#  [131] 160000  45000 100000 160000  35000  55000 140000  50000  60000 120000
#  [141]  40000 110000  50000 135000  40000  90000 150000  60000  80000 175000
#  [151]  45000 120000 140000  35000  95000 110000  50000 115000 185000  40000
#  [161]  90000 175000  45000  80000 120000  35000 110000 150000  50000 105000
#  [171] 180000  40000 140000  45000  85000 140000  50000  80000 170000  40000
#  [181] 105000 145000  40000  85000 130000  95000 100000 180000  35000  95000
#  [191] 170000  45000  95000 120000  40000  90000 155000  55000 110000 180000
#  [201]  45000 130000  45000  90000 160000  50000 120000 170000  40000 110000
#  [211] 150000  40000  85000 130000 100000  95000 180000  35000 100000 170000
# [3081] 136986 136662 191510 177347  82944 188288 141090 152726 124141  67556
# [3091] 182768 148727  91903 147708 163209 120288 170226 134979 137489  83577
# [3101] 117904 134482 184660 100151  88678 181285 154990 108204 175684  77766
# [3111] 192211 144647 162231 121120  79652 177002  87584 131860 182013 108799
# [3121] 135378 183530 150901  82697 194638 130356 152560 121432  63789 183690
# [3131] 151310 100358 148437 168691  50000 100000  60000  90000  70000 170000
# [3141] 130000  50000 120000  80000 200000 100000  55000 170000  90000  80000
# [3151] 180000  60000 120000  70000 210000 140000  50000 110000  60000 160000
# [3161]  75000 200000 100000  55000 170000  90000  80000 180000  60000 120000
# [3171]  70000 210000 140000  50000 110000  60000 160000  75000 200000 100000
# [3181]  55000 170000  90000  80000 180000  60000 120000  70000 210000 140000
# [3191]  50000 110000  60000 160000  75000 200000 100000  55000 170000  90000
# [3201]  80000 180000  60000 120000  70000 210000 140000  50000 110000  60000
# [3211] 160000  75000 200000 100000  55000 170000  90000  80000 180000  60000
# [3221] 120000  70000 210000 140000  50000 110000  60000 160000  75000 200000
# [3231] 100000  55000 170000  90000  80000 180000  60000 120000  70000 210000
# [3241] 140000  50000 110000  60000 160000  75000 200000 100000  55000 170000
# [3251]  90000  80000 180000  60000 120000  70000 210000 140000  80000  70000
# [3261] 180000  60000 120000  70000 210000 140000  50000 110000  60000 160000
# [3271]  75000 200000 100000  55000 170000  90000  80000 180000  60000 120000
# [3281]  70000 210000 140000  50000 110000  60000 160000  75000 200000 100000
# [3291]  55000 170000  90000  80000 180000  60000 120000  70000 210000 140000
# [3301]  50000 110000  60000 160000  75000 200000 100000  55000 170000  90000
# [3311]  80000 180000  60000 120000  70000 210000 140000  50000 110000  60000
# [3321] 160000  75000 200000 100000  55000 170000  90000  80000 180000  60000
# [3331] 120000  70000 210000 140000  50000 110000  60000 160000  75000 200000
# [3341] 100000  55000 170000  90000  80000 180000  60000 120000  70000 210000
# [3351] 140000  50000 110000  60000 160000  75000 200000 100000  55000 170000
# [3361]  90000  80000 180000  60000 120000  70000 210000 140000  50000 110000
# [3371]  60000 160000  75000 200000 100000  55000 170000  90000  80000 180000
# [3381]  60000 120000  80000  60000  50000 160000 120000  40000 100000  75000
# [3391] 140000  50000 110000  45000  55000 130000  50000  80000  45000  32000
# [3401] 120000  65000  95000  80000  38000 110000  45000  89000  32000  70000
# [3411] 150000  40000 105000  65000 140000  50000  35000 115000  70000  80000
# [3421]  30000 135000  40000 105000  35000 120000  55000  45000 140000  55000
# [3431] 115000  70000  38000 135000  45000  85000  32000 150000  65000  32000
# [3441] 120000  40000  95000  35000 140000  55000  80000 135000  45000  95000
# [3451]  32000  70000 120000  70000  85000  33000 150000  50000  32000 115000
# [3461]  40000 105000  35000 135000  65000  80000 140000  45000  95000  32000
# [3471]  70000 120000  70000  85000  33000 150000  50000  32000 115000  40000
# [3481] 105000  35000 135000  65000  80000 140000  45000  95000  32000  70000
# [3491] 120000  70000  85000  33000 150000  50000  32000 115000  40000 105000
# [3501]  35000 135000  65000  80000 140000  45000  95000  32000  70000 120000
# [6321]  95000  35000 100000  70000  50000 120000  40000  50000 140000  40000
# [6331] 100000  30000  75000  40000 180000  80000  35000 120000  45000  90000
# [6341]  55000 160000  40000 170000  40000  95000  35000 110000  75000  50000
# [6351] 120000  40000 150000  70000 190000  40000  75000 140000  35000 120000
# [6361]  80000  35000 130000  40000  90000  55000 180000  45000 190000  50000
# [6371]  55000 130000  35000 120000  95000  35000 140000  40000  80000  55000
# [6381] 190000  75000 170000  50000  55000 130000  35000 120000  95000  35000
# [6391] 140000  40000  80000  55000 190000  75000 170000  50000  55000 130000
# [6401]  35000 120000  95000  35000 140000  40000  80000  55000 190000  75000
# [6411] 170000  50000  55000 130000  35000 120000  95000  35000 140000  40000
# [6421]  80000  55000 190000  75000 170000  50000  55000 130000  35000 120000
# [6431]  95000  35000 140000  40000  80000  55000 190000  75000 170000  50000
# [6441]  55000 130000  35000 120000  95000  35000 140000  40000  80000  55000
# [6451] 190000 110000  40000 150000  55000  70000 160000  35000 100000  90000
# [6461]  50000 140000  40000 180000  90000  35000 120000  45000  80000  55000
# [6471] 180000  75000 190000  40000  70000 150000  35000 120000  80000  35000
# [6481] 130000  40000  90000  55000 180000  45000 190000  50000  55000 130000
# [6491]  35000 120000  95000  35000 140000  40000  80000  55000 190000  75000
# [6501] 170000  50000  55000 130000  35000 120000  95000  35000 140000  40000
# [6511]  80000  55000 190000  75000 170000  50000  55000 130000  35000 120000
# [6521]  95000  35000 140000  40000  80000  55000 190000  75000 170000  50000
# [6531]  55000 130000  35000 120000  95000  35000 140000  40000  80000  55000
# [6541] 190000  75000 170000  50000  55000 130000  35000 120000  95000  35000
# [6551] 140000  40000  80000  55000 190000  75000 170000  50000  55000 130000
# [6561]  35000 120000  95000  35000 140000  40000  80000  55000 190000  75000
# [6571] 170000  50000  55000 130000  35000 120000  45000 160000  70000  75000
# [6581] 170000  35000 110000  80000  55000 150000  40000 190000  80000  35000
# [6591] 130000  45000  90000  55000 190000  90000 200000  40000  70000 160000
# [6601]  35000 130000  95000  35000 140000  40000  90000  55000 190000  75000
# [6611] 200000  50000  55000 140000  35000 130000 100000  35000 150000  40000
# [6621]  80000  55000 190000  90000 200000  40000  70000 160000  35000 130000
# [6631]  95000  35000 140000  40000  90000  55000 190000  75000 200000  50000
# [6641]  55000 140000  35000 130000 100000  35000 150000  40000  80000  55000
# [6651] 190000  90000 200000  40000  70000 160000  35000 130000  95000  35000
# [6661] 140000  40000  90000  55000 190000  75000 200000  50000  55000 140000
# [6671]  35000 130000 100000  35000 150000  40000  80000  55000 190000  90000
# [6681] 200000  40000  70000 160000  35000 130000  95000  35000 140000  40000
# [6691]  90000  55000 190000  75000 200000  50000  55000 140000  35000

# %%
last_column <- salary[, ncol(salary)]
class(last_column)
# Out:
# [1] "integer"

# %% [markdown]
# The class of the output is an integer vector.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 2.3</font>
#
# * Using numeric indexing and the `nrow()` function, extract the last row of the `salary` data frame.
#
# * What is the data structure of your output [i.e. `class()`]?

# %%
salary[nrow(salary),]
# Out:
#      Age Gender Education.Level Job.Title       Years.of.Experience Salary
# 6704 26  Female HS              Sales Executive 1                   35000

# %% [markdown]
# The class of the outout is anther data frame.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 2.4</font>
#
# * Using numeric vector-based indexing, simultaneously extract the entries in rows 5 and 4,323 and columns 2 and 4.
#
# * What is the data structure of your output [i.e. `class()`]?

# %%
salary[c(5, 4323), c(2, 4)]
# Out:
#      Gender Job.Title
# 5    Male   Director
# 4326 Female Junior Sales Associate

# %% [markdown]
# The output is another data frame.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 2.5</font>
#
# * What can you conclude about the class of output when subsetting multiple entries/rows from multiple columns?
# * What can you conclude about the class of output when subsetting multiple entries/rows from a single column?

# %% [markdown]
# The class output when subsetting multiple rows from multiple columns is another data frame. The class of output when subsetting multiple rows from a single column is a vector.

# %% [markdown]
# <br>
#
# <br>

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ####<font color=red>Task 3</font> - Boolean-based Subsetting for Data Analysis

# %% [markdown]
# <font color=red>Task 3.1</font>
#
# * Visualize the relationship between `Salary` and `Education.Level` using the appropiate data visualization
#
# * Write your observations in a text cell.

# %%
boxplot(salary$Salary ~ salary$Education.Level,
        xlab = "Education Level",
        ylab = "Salary ($)",
        main = "Salary by Education Level")
# Out:
# Plot with title “Salary by Education Level”

# %% [markdown]
# Higher median slaries are associated with higher education levels. There are individuals with high school degrees with very high salaries that appear to be outliers. There are also individuals with a PhD degree with very low salaries that appear to be outliers. Aside from outliers, salary variability of those with high school degrees appears smaller than for the other education levels.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 3.2</font>
#
# * Use subsetting to create a data frame for the following education levels (you should have four data frames in total):
#   * HS
#   * BS
#   * MS
#   * PhD
#
# * How many rows are in each of the four data frames? What is the most common degree in the dataset? Write you answer in a text cell.
#
# * Verify you answer by applying the `table()` function to the `Education.Level` variable from the original `salary` data frame.

# %%
# subsetting & creating new data frames

# high school
salary_hs <- salary[salary$Education.Level == "HS", ]

# bachelors
salary_bs <- salary[salary$Education.Level == "BS", ]

# masters
salary_ms <- salary[salary$Education.Level == "MS", ]

# PhD
salary_phd <- salary[salary$Education.Level == "PhD", ]

# find the number of rows for each education level
nrow(salary_hs)
nrow(salary_bs)
nrow(salary_ms)
nrow(salary_phd)
# Out:
# [1] 448
# [1] 3021
# [1] 1860
# [1] 1369

# %%
# check with `table` using the original data
table(salary$Education.Level)
# Out:
# missing      HS      BS      MS     PhD
#       1     448    3021    1860    1369

# %% [markdown]
# There are 448 HS, 3021 BS, 1860 MS, and 1369 PhD degrees. The most common degree is a BS degree.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 3.3</font>
#
# * Calculate the ***average*** salary for each education level using the data frame created in Task 3.2.
#
# * Do your computed averages align with your observations from you visualization in Task 3.1? Write you observations in a text cell.

# %%
# high school
mean(salary_hs$Salary)

# bs
mean(salary_bs$Salary)

#ms
mean(salary_ms$Salary)

#phd
mean(salary_phd$Salary)
# Out:
# [1] 36706.69
# [1] 95082.91
# [1] 130112.1
# [1] 165651.5

# %%
# could use the `round()`
round(mean(salary_hs$Salary), 4) # high school
# Out:
# [1] 36706.69

# %% [markdown]
# The average salaries align with the observations from the boxplot, which shows that salaries generally increase with education.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 3.4</font>
#
# * Calculate the ***standard deviation*** of salaries for each education level using the data frame created in Task 3.2.
#
# * Do your computed standard deviations align with your observations from you visualization in Task 3.1? Write you observations in a text cell.

# %%
# high school
sd(salary_hs$Salary)

# bs
sd(salary_bs$Salary)

#ms
sd(salary_ms$Salary)

#phd
sd(salary_phd$Salary)
# Out:
# [1] 22549.13
# [1] 44091.79
# [1] 40640.82
# [1] 34339.75

# %% [markdown]
# The standard deviations of salaries align with the observations from the boxplot, which shows that salaries of individuals with BS degrees have more variability than the salaries of other education levels.

# %% [markdown]
# <br>
#
# <br>

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ####<font color=red>Task 4</font> - More Subsetting Practice

# %% [markdown]
# <font color=red>Task 4.1</font>
#
# * What is the average salary for males in the dataset?
# * What is the average salary for females in the dataset?
# * What is the average salary for individuals who specified `"Other"` as their ender?

# %%
# salary for males
mean(salary$Salary[salary$Gender == "Male"])

# salary for females
mean(salary$Salary[salary$Gender == "Female"])

# salary for other
mean(salary$Salary[salary$Gender == "Other"])
# Out:
# [1] 121389.9
# [1] 107889
# [1] 125869.9

# %% [markdown]
# The average salary for males in the data set is ~ \$121,390. The average salary for females in the data set is ~ \$107, 889. The average salary for individuals who specified "Other" as their ender is ~ \$125,670.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 4.2</font>
#
# * From 4.1, which gender has the highest salary on average?
#
# * Determine the number of individuals in each gender category using `table()`.
#
# * Which sample size appears somewhat unreliable? Explain your answer in a text cell.

# %%
table(salary$Gender)
# Out:
# Female   Male  Other
#   3013   3672     14

# %% [markdown]
# Although "Other" gender category has the highest salary on average, the sample size is quite small (14 individuals). Therefore, the average may be an unreliable estimate.

# %% [markdown]
# <br>
#
# <br>

# %% [markdown]
# <br>
#
# ---

# %% [markdown]
# ####<font color=red>Task 5</font> - More Subsetting Practice

# %% [markdown]
# <font color=red>Task 5.1</font>
#
# * What is the average salary of a "Data Scientist"?
#
# * What is the average salary of a "Data Analyst"?

# %%
# data scientist
mean(salary$Salary[salary$Job.Title == "Data Scientist"])

# data analyst
mean(salary$Salary[salary$Job.Title == "Data Analyst"])
# Out:
# [1] 166106
# [1] 125090.9

# %% [markdown]
# The average salary of a Data Scientist is ~ \$166,106 , and the average salary of a Data Analyst is ~ \$125,091.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 5.2</font>
#
# * What is the average age of a "Data Scientist"?
#
# * What is the average age of a "Data Analyst"?

# %%
# data scientist
mean(salary$Age[salary$Job.Title == "Data Scientist"])

# data analyst
mean(salary$Age[salary$Job.Title == "Data Analyst"])
# Out:
# [1] 36.06402
# [1] 28.68595

# %% [markdown]
# The average age of a Data Scientist is 36 years old. The average age of a Data Analyst is ~ 28 - 29 years old.

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 5.3</font>
#
# * What is the most common education level of a Data Scientist?
#
#   [Hint: Subset "Data Scientist" first, then use the `table()` function on `Education.Level`]
#
# * What is the most common education level of a Data Analyst?

# %%
# data scientist
table(salary$Education.Level[salary$Job.Title == "Data Scientist"])

# data analyst
table(salary$Education.Level[salary$Job.Title == "Data Analyst"])
# Out:
# missing      HS      BS      MS     PhD
#       0       0       8     115     330
# missing      HS      BS      MS     PhD
#       0       0     287      76       0

# %% [markdown]
# The most common education level of a Data Scientist is a PhD, and the most common education level of a Data Analyst is a Bachelors (BS).

# %% [markdown]
# <br>

# %% [markdown]
# <font color=red>Task 5.4</font>
#
# * What is the difference between a Data Scientist and a Data Analyst? You may search online!

# %% [markdown]
# A Data Scientist used advanced statistics and programming such as Python and R to analyze raw data to be able to build predictive models for future trends. A Data Analyst focuses on interpreting pre-existing data to be able to create reports and visualizations using SQL, Tableau, and Excel for short term business decisions.

# %% [markdown]
# <br>
#
# <br>
